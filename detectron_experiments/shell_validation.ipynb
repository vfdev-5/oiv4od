# %% [markdown]
# # Run validation scripts in cmd
# and keep history

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
# Out:
# <style>.container { width:98% !important; }</style>

# %%
import os

# %%
pwd=!cd ../ && echo ${PWD}/
os.environ['DATA_DIR'] = pwd[0] + "input"

# %%
Detectron = "../detectron_source/"

# %%
def get_gt_bboxes_labels(image_id, annotations):
    selected_annotations = [a for a in gt_annotations if a['image_id'] == image_id]
    if len(selected_annotations) == 0:
        return []
    
    bboxes_labels = [(a['bbox'], str(a['category_id'])) for a in selected_annotations]
    return bboxes_labels

# %%
# !pip install --upgrade image-dataset-viz
from image_dataset_viz import render_datapoint, bbox_to_points, xywh_to_xyxy

# %%
def get_img_gt_target(img_path, image_id, annotations):
    img = Image.open(img_path + image_id + ".jpg")
    targets = [(bbox_to_points(xywh_to_xyxy(b)), l) for b, l in get_gt_bboxes_labels(image_id, gt_annotations)]
    return render_datapoint(img, targets, output_size=(430, 430))

# %% [markdown]
# ## Validate models
#
# Validation dataset contains: 4162 images

# %%
# !find /home/data/as_mscoco/val/ -name *.jpg | wc -l
# Out:
# 41620

# %%
41620 * 0.1
# Out:
# 4162.0

# %% [markdown]
# ## Run training - Finetunning of Faster-RCNN

# %%
from datetime import datetime
now = datetime.now()


config_name = "faster_rcnn_X-101-64x4d-FPN_1x"
output_path = "/home/data/output-OpenImagesObjectDetections/{}/{}".format(config_name, now.strftime("%Y%m%d_%H%M"))
weights_path = "weights/Faster-RCNN-X-101-64x4d-FPN/model_final.pkl" 

config = "configs/open_images_v4/{}.yaml".format(config_name)
other_confs = "OUTPUT_DIR {} ".format(output_path) + \
                "TRAIN.WEIGHTS {} ".format(weights_path) + \
                "TRAIN.SNAPSHOT_ITERS 20000 " + \
                "TRAIN.IMS_PER_BATCH 2 " + \
                "SOLVER.BASE_LR 0.001 " + \
                "SOLVER.GAMMA 0.5 " + \
                "SOLVER.WARM_UP_ITERS 100 "

print("Output dir: ", output_path)                
# !mkdir -p {output_path}
# !echo "python2 tools/train_net.py --cfg {config} {other_confs}" > {output_path}/run.cmd
# !python2 {Detectron}/tools/train_net.py --cfg {config} {other_confs}
# Out:
# ('Output dir: ', '/home/storage_ntfs_1tb/output-OpenImagesObjectDetections/faster_rcnn_X-101-64x4d-FPN_1x/20180728_0006')
# Found Detectron ops lib: /usr/local/caffe2_build/lib/libcaffe2_detectron_ops_gpu.so
# E0728 00:06:04.243274 15364 init_intrinsics_check.cc:54] CPU feature avx is present on your machine, but the Caffe2 binary is not compiled with it. It means you may not get the full speed of your CPU.
# E0728 00:06:04.243732 15364 init_intrinsics_check.cc:54] CPU feature avx2 is present on your machine, but the Caffe2 binary is not compiled with it. It means you may not get the full speed of your CPU.
# E0728 00:06:04.243741 15364 init_intrinsics_check.cc:54] CPU feature fma is present on your machine, but the Caffe2 binary is not compiled with it. It means you may not get the full speed of your CPU.
# INFO train_net.py:  95: Called with args:
# INFO train_net.py:  96: Namespace(cfg_file='configs/open_images_v4/faster_rcnn_X-101-64x4d-FPN_1x.yaml', multi_gpu_testing=False, opts=['NUM_GPUS', '1', 'OUTPUT_DIR', '/home/storage_ntfs_1tb/output-OpenImagesObjectDetections/faster_rcnn_X-101-64x4d-FPN_1x/20180728_0006', 'TRAIN.WEIGHTS', 'weights/Faster-RCNN-X-101-64x4d-FPN/model_final.pkl', 'TRAIN.SNAPSHOT_ITERS', '20000', 'TRAIN.IMS_PER_BATCH', '1', 'SOLVER.BASE_LR', '0.001', 'SOLVER.GAMMA', '0.5', 'SOLVER.WARM_UP_ITERS', '100', 'DATA_LOADER.MINIBATCH_QUEUE_SIZE', '64', 'DATA_LOADER.BLOBS_QUEUE_CAPACITY', '16', 'DATA_LOADER.NUM_THREADS', '4'], skip_test=False)
# INFO train_net.py: 102: Training with config:
# INFO train_net.py: 103: {'BBOX_XFORM_CLIP': 4.135166556742356,
#  'CLUSTER': {'ON_CLUSTER': False},
#  'DATA_LOADER': {'BLOBS_QUEUE_CAPACITY': 16,
#                  'MINIBATCH_QUEUE_SIZE': 64,
#                  'NUM_THREADS': 4},
#  'DEDUP_BOXES': 0.0625,
#  'DOWNLOAD_CACHE': '/tmp/detectron-download-cache',
#  'EPS': 1e-14,
#  'EXPECTED_RESULTS': [],
#  'EXPECTED_RESULTS_ATOL': 0.005,
#  'EXPECTED_RESULTS_EMAIL': '',
#  'EXPECTED_RESULTS_RTOL': 0.1,
#  'FAST_RCNN': {'CONV_HEAD_DIM': 256,
#                'MLP_HEAD_DIM': 1024,
#                'NUM_STACKED_CONVS': 4,
#                'ROI_BOX_HEAD': 'fast_rcnn_heads.add_roi_2mlp_head',
#                'ROI_XFORM_METHOD': 'RoIAlign',
#                'ROI_XFORM_RESOLUTION': 7,
#                'ROI_XFORM_SAMPLING_RATIO': 2},
#  'FPN': {'COARSEST_STRIDE': 32,
#          'DIM': 256,
#          'EXTRA_CONV_LEVELS': False,
#          'FPN_ON': True,
#          'MULTILEVEL_ROIS': True,
#          'MULTILEVEL_RPN': True,
#          'ROI_CANONICAL_LEVEL': 4,
#          'ROI_CANONICAL_SCALE': 224,
#          'ROI_MAX_LEVEL': 5,
#          'ROI_MIN_LEVEL': 2,
#          'RPN_ANCHOR_START_SIZE': 32,
#          'RPN_ASPECT_RATIOS': (0.5, 1, 2),
#          'RPN_MAX_LEVEL': 6,
#          'RPN_MIN_LEVEL': 2,
#          'USE_GN': False,
#          'ZERO_INIT_LATERAL': False},
#  'GROUP_NORM': {'DIM_PER_GP': -1, 'EPSILON': 1e-05, 'NUM_GROUPS': 32},
#  'KRCNN': {'CONV_HEAD_DIM': 256,
#            'CONV_HEAD_KERNEL': 3,
#            'CONV_INIT': 'GaussianFill',
#            'DECONV_DIM': 256,
#            'DECONV_KERNEL': 4,
#            'DILATION': 1,
#            'HEATMAP_SIZE': -1,
#            'INFERENCE_MIN_SIZE': 0,
#            'KEYPOINT_CONFIDENCE': 'bbox',
#            'LOSS_WEIGHT': 1.0,
#            'MIN_KEYPOINT_COUNT_FOR_VALID_MINIBATCH': 20,
#            'NMS_OKS': False,
#            'NORMALIZE_BY_VISIBLE_KEYPOINTS': True,
#            'NUM_KEYPOINTS': -1,
#            'NUM_STACKED_CONVS': 8,
#            'ROI_KEYPOINTS_HEAD': '',
#            'ROI_XFORM_METHOD': 'RoIAlign',
#            'ROI_XFORM_RESOLUTION': 7,
#            'ROI_XFORM_SAMPLING_RATIO': 0,
#            'UP_SCALE': -1,
#            'USE_DECONV': False,
#            'USE_DECONV_OUTPUT': False},
#  'MATLAB': 'matlab',
#  'MEMONGER': True,
#  'MEMONGER_SHARE_ACTIVATIONS': False,
#  'MODEL': {'BBOX_REG_WEIGHTS': (10.0, 10.0, 5.0, 5.0),
#            'CLS_AGNOSTIC_BBOX_REG': False,
#            'CONV_BODY': 'FPN.add_fpn_ResNet101_conv5_body',
#            'EXECUTION_TYPE': 'dag',
#            'FASTER_RCNN': True,
#            'KEYPOINTS_ON': False,
#            'MASK_ON': False,
#            'NUM_CLASSES': 601,
#            'RPN_ONLY': False,
#            'TYPE': 'generalized_rcnn'},
#  'MRCNN': {'CLS_SPECIFIC_MASK': True,
#            'CONV_INIT': 'GaussianFill',
#            'DILATION': 2,
#            'DIM_REDUCED': 256,
#            'RESOLUTION': 14,
#            'ROI_MASK_HEAD': '',
#            'ROI_XFORM_METHOD': 'RoIAlign',
#            'ROI_XFORM_RESOLUTION': 7,
#            'ROI_XFORM_SAMPLING_RATIO': 0,
#            'THRESH_BINARIZE': 0.5,
#            'UPSAMPLE_RATIO': 1,
#            'USE_FC_OUTPUT': False,
#            'WEIGHT_LOSS_MASK': 1.0},
#  'NUM_GPUS': 1,
#  'OUTPUT_DIR': '/home/storage_ntfs_1tb/output-OpenImagesObjectDetections/faster_rcnn_X-101-64x4d-FPN_1x/20180728_0006',
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'RESNETS': {'NUM_GROUPS': 64,
#              'RES5_DILATION': 1,
#              'SHORTCUT_FUNC': 'basic_bn_shortcut',
#              'STEM_FUNC': 'basic_bn_stem',
#              'STRIDE_1X1': False,
#              'TRANS_FUNC': 'bottleneck_transformation',
#              'WIDTH_PER_GROUP': 4},
#  'RETINANET': {'ANCHOR_SCALE': 4.0,
#                'ASPECT_RATIOS': (0.5, 1.0, 2.0),
#                'BBOX_REG_BETA': 0.11,
#                'BBOX_REG_WEIGHT': 1.0,
#                'CLASS_SPECIFIC_BBOX': False,
#                'INFERENCE_TH': 0.05,
#                'LOSS_ALPHA': 0.25,
#                'LOSS_GAMMA': 2.0,
#                'NEGATIVE_OVERLAP': 0.4,
#                'NUM_CONVS': 4,
#                'POSITIVE_OVERLAP': 0.5,
#                'PRE_NMS_TOP_N': 1000,
#                'PRIOR_PROB': 0.01,
#                'RETINANET_ON': False,
#                'SCALES_PER_OCTAVE': 3,
#                'SHARE_CLS_BBOX_TOWER': False,
#                'SOFTMAX': False},
#  'RFCN': {'PS_GRID_SIZE': 3},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/home/working_directory/ml/kaggle/OpenImagesObjectDetection/detectron_experiments',
#  'RPN': {'ASPECT_RATIOS': (0.5, 1, 2),
#          'RPN_ON': True,
#          'SIZES': (64, 128, 256, 512),
#          'STRIDE': 16},
#  'SOLVER': {'BASE_LR': 0.001,
#             'GAMMA': 0.5,
#             'LOG_LR_CHANGE_THRESHOLD': 1.1,
#             'LRS': [],
#             'LR_POLICY': 'steps_with_decay',
#             'MAX_ITER': 600000,
#             'MOMENTUM': 0.9,
#             'SCALE_MOMENTUM': True,
#             'SCALE_MOMENTUM_THRESHOLD': 1.1,
#             'STEPS': [0, 120000, 160000, 200000, 300000, 400000, 500000],
#             'STEP_SIZE': 30000,
#             'WARM_UP_FACTOR': 0.3333333333333333,
#             'WARM_UP_ITERS': 100,
#             'WARM_UP_METHOD': u'linear',
#             'WEIGHT_DECAY': 0.0001,
#             'WEIGHT_DECAY_GN': 0.0},
#  'TEST': {'BBOX_AUG': {'AREA_TH_HI': 32400,
#                        'AREA_TH_LO': 2500,
#                        'ASPECT_RATIOS': (),
#                        'ASPECT_RATIO_H_FLIP': False,
#                        'COORD_HEUR': 'UNION',
#                        'ENABLED': False,
#                        'H_FLIP': False,
#                        'MAX_SIZE': 4000,
#                        'SCALES': (),
#                        'SCALE_H_FLIP': False,
#                        'SCALE_SIZE_DEP': False,
#                        'SCORE_HEUR': 'UNION'},
#           'BBOX_REG': True,
#           'BBOX_VOTE': {'ENABLED': False,
#                         'SCORING_METHOD': 'ID',
#                         'SCORING_METHOD_BETA': 1.0,
#                         'VOTE_TH': 0.8},
#           'COMPETITION_MODE': True,
#           'DATASETS': ('open_images_v4_val_0.1',),
#           'DETECTIONS_PER_IM': 100,
#           'FORCE_JSON_DATASET_EVAL': True,
#           'KPS_AUG': {'AREA_TH': 32400,
#                       'ASPECT_RATIOS': (),
#                       'ASPECT_RATIO_H_FLIP': False,
#                       'ENABLED': False,
#                       'HEUR': 'HM_AVG',
#                       'H_FLIP': False,
#                       'MAX_SIZE': 4000,
#                       'SCALES': (),
#                       'SCALE_H_FLIP': False,
#                       'SCALE_SIZE_DEP': False},
#           'MASK_AUG': {'AREA_TH': 32400,
#                        'ASPECT_RATIOS': (),
#                        'ASPECT_RATIO_H_FLIP': False,
#                        'ENABLED': False,
#                        'HEUR': 'SOFT_AVG',
#                        'H_FLIP': False,
#                        'MAX_SIZE': 4000,
#                        'SCALES': (),
#                        'SCALE_H_FLIP': False,
#                        'SCALE_SIZE_DEP': False},
#           'MAX_SIZE': 1333,
#           'NMS': 0.5,
#           'PRECOMPUTED_PROPOSALS': False,
#           'PROPOSAL_FILES': (),
#           'PROPOSAL_LIMIT': 2000,
#           'RPN_MIN_SIZE': 0,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 1000,
#           'RPN_PRE_NMS_TOP_N': 1000,
#           'SCALE': 800,
#           'SCORE_THRESH': 0.05,
#           'SOFT_NMS': {'ENABLED': False, 'METHOD': 'linear', 'SIGMA': 0.5},
#           'WEIGHTS': ''},
#  'TRAIN': {'ASPECT_GROUPING': True,
#            'AUTO_RESUME': True,
#            'BATCH_SIZE_PER_IM': 512,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'COPY_WEIGHTS': False,
#            'CROWD_FILTER_THRESH': 0.5,
#            'DATASETS': ('open_images_v4_train_small',
#                         'open_images_v4_val_0.9'),
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'FREEZE_AT': 2,
#            'FREEZE_CONV_BODY': True,
#            'GT_MIN_AREA': -1,
#            'IMS_PER_BATCH': 1,
#            'MAX_SIZE': 1333,
#            'PROPOSAL_FILES': (),
#            'RPN_BATCH_SIZE_PER_IM': 256,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 0,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 2000,
#            'RPN_STRADDLE_THRESH': 0,
#            'SCALES': (800,),
#            'SNAPSHOT_ITERS': 20000,
#            'USE_FLIPPED': True,
#            'WEIGHTS': 'weights/Faster-RCNN-X-101-64x4d-FPN/model_final.pkl'},
#  'USE_NCCL': False,
#  'VIS': False,
#  'VIS_TH': 0.9}
# INFO train.py: 152: Building model: generalized_rcnn
# WARNING cnn.py:  40: [====DEPRECATE WARNING====]: you are creating an object from CNNModelHelper class which will be deprecated soon. Please use ModelHelper object with brew module. For more information, please refer to caffe2.ai and python/brew.py, python/brew_test.py for more information.
# WARNING memonger.py:  70: NOTE: Executing memonger to optimize gradient memory
# INFO memonger.py: 112: Memonger memory optimization took 0.00454902648926 secs
# INFO train.py: 200: Loading dataset: ('open_images_v4_train_small', 'open_images_v4_val_0.9')
# loading annotations into memory...
# Done (t=6.16s)
# creating index...
# index created!
# INFO roidb.py:  49: Appending horizontally-flipped training examples...
# INFO roidb.py:  51: Loaded dataset: open_images_v4_train_small
# loading annotations into memory...
# Done (t=3.35s)
# creating index...
# index created!
# INFO roidb.py:  49: Appending horizontally-flipped training examples...
# INFO roidb.py:  51: Loaded dataset: open_images_v4_val_0.9
# INFO roidb.py: 135: Filtered 0 roidb entries: 280548 -> 280548
# INFO roidb.py:  67: Computing bounding-box regression targets...
# INFO roidb.py:  69: done
# INFO train.py: 204: 280548 roidb entries
# INFO net.py:  59: Loading weights from: weights/Faster-RCNN-X-101-64x4d-FPN/model_final.pkl
# INFO train.py: 188: Outputs saved to: /home/storage_ntfs_1tb/output-OpenImagesObjectDetections/faster_rcnn_X-101-64x4d-FPN_1x/20180728_0006/train/open_images_v4_train_small:open_images_v4_val_0.9/generalized_rcnn
# INFO loader.py: 229: Pre-filling mini-batch queue...
# INFO loader.py: 234:   [0/64]
# INFO loader.py: 234:   [0/64]
# INFO loader.py: 234:   [1/64]
# INFO loader.py: 234:   [3/64]
# INFO loader.py: 234:   [4/64]
# INFO loader.py: 234:   [6/64]
# INFO loader.py: 234:   [5/64]
# INFO loader.py: 234:   [10/64]
# INFO loader.py: 234:   [16/64]
# INFO loader.py: 234:   [23/64]
# INFO loader.py: 234:   [29/64]
# INFO loader.py: 234:   [35/64]
# INFO loader.py: 234:   [40/64]
# INFO loader.py: 234:   [46/64]
# INFO loader.py: 234:   [52/64]
# INFO loader.py: 234:   [57/64]
# INFO loader.py: 234:   [61/64]
# INFO detector.py: 479: Changing learning rate 0.000000 -> 0.000333 at iter 0
# INFO net.py: 220: Printing model: generalized_rcnn
# INFO net.py: 257: data                        : (1, 3, 800, 1024)    => conv1                       : (1, 64, 400, 512)    ------- (op: Conv)
# INFO net.py: 257: conv1                       : (1, 64, 400, 512)    => conv1                       : (1, 64, 400, 512)    ------- (op: AffineChannel)
# INFO net.py: 257: conv1                       : (1, 64, 400, 512)    => conv1                       : (1, 64, 400, 512)    ------- (op: Relu)
# INFO net.py: 257: conv1                       : (1, 64, 400, 512)    => pool1                       : (1, 64, 200, 256)    ------- (op: MaxPool)
# INFO net.py: 257: pool1                       : (1, 64, 200, 256)    => res2_0_branch2a             : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_0_branch2a             : (1, 256, 200, 256)   => res2_0_branch2a             : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_0_branch2a             : (1, 256, 200, 256)   => res2_0_branch2a             : (1, 256, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res2_0_branch2a             : (1, 256, 200, 256)   => res2_0_branch2b             : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_0_branch2b             : (1, 256, 200, 256)   => res2_0_branch2b             : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_0_branch2b             : (1, 256, 200, 256)   => res2_0_branch2b             : (1, 256, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res2_0_branch2b             : (1, 256, 200, 256)   => res2_0_branch2c             : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_0_branch2c             : (1, 256, 200, 256)   => res2_0_branch2c_bn          : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: pool1                       : (1, 64, 200, 256)    => res2_0_branch1              : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_0_branch1              : (1, 256, 200, 256)   => res2_0_branch1_bn           : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_0_branch2c_bn          : (1, 256, 200, 256)   => res2_0_branch2c_bn          : (1, 256, 200, 256)   ------- (op: Sum)
# INFO net.py: 257: res2_0_branch1_bn           : (1, 256, 200, 256)   => res2_0_branch2c_bn          : (1, 256, 200, 256)   ------|
# INFO net.py: 257: res2_0_branch2c_bn          : (1, 256, 200, 256)   => res2_0_branch2c_bn          : (1, 256, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res2_0_branch2c_bn          : (1, 256, 200, 256)   => res2_1_branch2a             : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_1_branch2a             : (1, 256, 200, 256)   => res2_1_branch2a             : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_1_branch2a             : (1, 256, 200, 256)   => res2_1_branch2a             : (1, 256, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res2_1_branch2a             : (1, 256, 200, 256)   => res2_1_branch2b             : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_1_branch2b             : (1, 256, 200, 256)   => res2_1_branch2b             : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_1_branch2b             : (1, 256, 200, 256)   => res2_1_branch2b             : (1, 256, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res2_1_branch2b             : (1, 256, 200, 256)   => res2_1_branch2c             : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_1_branch2c             : (1, 256, 200, 256)   => res2_1_branch2c_bn          : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_1_branch2c_bn          : (1, 256, 200, 256)   => res2_1_branch2c_bn          : (1, 256, 200, 256)   ------- (op: Sum)
# INFO net.py: 257: res2_0_branch2c_bn          : (1, 256, 200, 256)   => res2_1_branch2c_bn          : (1, 256, 200, 256)   ------|
# INFO net.py: 257: res2_1_branch2c_bn          : (1, 256, 200, 256)   => res2_1_branch2c_bn          : (1, 256, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res2_1_branch2c_bn          : (1, 256, 200, 256)   => res2_2_branch2a             : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_2_branch2a             : (1, 256, 200, 256)   => res2_2_branch2a             : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_2_branch2a             : (1, 256, 200, 256)   => res2_2_branch2a             : (1, 256, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res2_2_branch2a             : (1, 256, 200, 256)   => res2_2_branch2b             : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_2_branch2b             : (1, 256, 200, 256)   => res2_2_branch2b             : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_2_branch2b             : (1, 256, 200, 256)   => res2_2_branch2b             : (1, 256, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res2_2_branch2b             : (1, 256, 200, 256)   => res2_2_branch2c             : (1, 256, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res2_2_branch2c             : (1, 256, 200, 256)   => res2_2_branch2c_bn          : (1, 256, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_2_branch2c_bn          : (1, 256, 200, 256)   => res2_2_sum                  : (1, 256, 200, 256)   ------- (op: Sum)
# INFO net.py: 257: res2_1_branch2c_bn          : (1, 256, 200, 256)   => res2_2_sum                  : (1, 256, 200, 256)   ------|
# INFO net.py: 257: res2_2_sum                  : (1, 256, 200, 256)   => res2_2_sum                  : (1, 256, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res2_2_sum                  : (1, 256, 200, 256)   => res2_2_sum                  : (1, 256, 200, 256)   ------- (op: StopGradient)
# INFO net.py: 257: res2_2_sum                  : (1, 256, 200, 256)   => res3_0_branch2a             : (1, 512, 200, 256)   ------- (op: Conv)
# INFO net.py: 257: res3_0_branch2a             : (1, 512, 200, 256)   => res3_0_branch2a             : (1, 512, 200, 256)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_0_branch2a             : (1, 512, 200, 256)   => res3_0_branch2a             : (1, 512, 200, 256)   ------- (op: Relu)
# INFO net.py: 257: res3_0_branch2a             : (1, 512, 200, 256)   => res3_0_branch2b             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_0_branch2b             : (1, 512, 100, 128)   => res3_0_branch2b             : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_0_branch2b             : (1, 512, 100, 128)   => res3_0_branch2b             : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_0_branch2b             : (1, 512, 100, 128)   => res3_0_branch2c             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_0_branch2c             : (1, 512, 100, 128)   => res3_0_branch2c_bn          : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res2_2_sum                  : (1, 256, 200, 256)   => res3_0_branch1              : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_0_branch1              : (1, 512, 100, 128)   => res3_0_branch1_bn           : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_0_branch2c_bn          : (1, 512, 100, 128)   => res3_0_branch2c_bn          : (1, 512, 100, 128)   ------- (op: Sum)
# INFO net.py: 257: res3_0_branch1_bn           : (1, 512, 100, 128)   => res3_0_branch2c_bn          : (1, 512, 100, 128)   ------|
# INFO net.py: 257: res3_0_branch2c_bn          : (1, 512, 100, 128)   => res3_0_branch2c_bn          : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_0_branch2c_bn          : (1, 512, 100, 128)   => res3_1_branch2a             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_1_branch2a             : (1, 512, 100, 128)   => res3_1_branch2a             : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_1_branch2a             : (1, 512, 100, 128)   => res3_1_branch2a             : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_1_branch2a             : (1, 512, 100, 128)   => res3_1_branch2b             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_1_branch2b             : (1, 512, 100, 128)   => res3_1_branch2b             : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_1_branch2b             : (1, 512, 100, 128)   => res3_1_branch2b             : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_1_branch2b             : (1, 512, 100, 128)   => res3_1_branch2c             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_1_branch2c             : (1, 512, 100, 128)   => res3_1_branch2c_bn          : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_1_branch2c_bn          : (1, 512, 100, 128)   => res3_1_branch2c_bn          : (1, 512, 100, 128)   ------- (op: Sum)
# INFO net.py: 257: res3_0_branch2c_bn          : (1, 512, 100, 128)   => res3_1_branch2c_bn          : (1, 512, 100, 128)   ------|
# INFO net.py: 257: res3_1_branch2c_bn          : (1, 512, 100, 128)   => res3_1_branch2c_bn          : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_1_branch2c_bn          : (1, 512, 100, 128)   => res3_2_branch2a             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_2_branch2a             : (1, 512, 100, 128)   => res3_2_branch2a             : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_2_branch2a             : (1, 512, 100, 128)   => res3_2_branch2a             : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_2_branch2a             : (1, 512, 100, 128)   => res3_2_branch2b             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_2_branch2b             : (1, 512, 100, 128)   => res3_2_branch2b             : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_2_branch2b             : (1, 512, 100, 128)   => res3_2_branch2b             : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_2_branch2b             : (1, 512, 100, 128)   => res3_2_branch2c             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_2_branch2c             : (1, 512, 100, 128)   => res3_2_branch2c_bn          : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_2_branch2c_bn          : (1, 512, 100, 128)   => res3_2_branch2c_bn          : (1, 512, 100, 128)   ------- (op: Sum)
# INFO net.py: 257: res3_1_branch2c_bn          : (1, 512, 100, 128)   => res3_2_branch2c_bn          : (1, 512, 100, 128)   ------|
# INFO net.py: 257: res3_2_branch2c_bn          : (1, 512, 100, 128)   => res3_2_branch2c_bn          : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_2_branch2c_bn          : (1, 512, 100, 128)   => res3_3_branch2a             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_3_branch2a             : (1, 512, 100, 128)   => res3_3_branch2a             : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_3_branch2a             : (1, 512, 100, 128)   => res3_3_branch2a             : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_3_branch2a             : (1, 512, 100, 128)   => res3_3_branch2b             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_3_branch2b             : (1, 512, 100, 128)   => res3_3_branch2b             : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_3_branch2b             : (1, 512, 100, 128)   => res3_3_branch2b             : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_3_branch2b             : (1, 512, 100, 128)   => res3_3_branch2c             : (1, 512, 100, 128)   ------- (op: Conv)
# INFO net.py: 257: res3_3_branch2c             : (1, 512, 100, 128)   => res3_3_branch2c_bn          : (1, 512, 100, 128)   ------- (op: AffineChannel)
# INFO net.py: 257: res3_3_branch2c_bn          : (1, 512, 100, 128)   => res3_3_sum                  : (1, 512, 100, 128)   ------- (op: Sum)
# INFO net.py: 257: res3_2_branch2c_bn          : (1, 512, 100, 128)   => res3_3_sum                  : (1, 512, 100, 128)   ------|
# INFO net.py: 257: res3_3_sum                  : (1, 512, 100, 128)   => res3_3_sum                  : (1, 512, 100, 128)   ------- (op: Relu)
# INFO net.py: 257: res3_3_sum                  : (1, 512, 100, 128)   => res4_0_branch2a             : (1, 1024, 100, 128)  ------- (op: Conv)
# INFO net.py: 257: res4_0_branch2a             : (1, 1024, 100, 128)  => res4_0_branch2a             : (1, 1024, 100, 128)  ------- (op: AffineChannel)
# INFO net.py: 257: res4_0_branch2a             : (1, 1024, 100, 128)  => res4_0_branch2a             : (1, 1024, 100, 128)  ------- (op: Relu)
# INFO net.py: 257: res4_0_branch2a             : (1, 1024, 100, 128)  => res4_0_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_0_branch2b             : (1, 1024, 50, 64)    => res4_0_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_0_branch2b             : (1, 1024, 50, 64)    => res4_0_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_0_branch2b             : (1, 1024, 50, 64)    => res4_0_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_0_branch2c             : (1, 1024, 50, 64)    => res4_0_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res3_3_sum                  : (1, 512, 100, 128)   => res4_0_branch1              : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_0_branch1              : (1, 1024, 50, 64)    => res4_0_branch1_bn           : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_0_branch2c_bn          : (1, 1024, 50, 64)    => res4_0_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_0_branch1_bn           : (1, 1024, 50, 64)    => res4_0_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_0_branch2c_bn          : (1, 1024, 50, 64)    => res4_0_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_0_branch2c_bn          : (1, 1024, 50, 64)    => res4_1_branch2a             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_1_branch2a             : (1, 1024, 50, 64)    => res4_1_branch2a             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_1_branch2a             : (1, 1024, 50, 64)    => res4_1_branch2a             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_1_branch2a             : (1, 1024, 50, 64)    => res4_1_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_1_branch2b             : (1, 1024, 50, 64)    => res4_1_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_1_branch2b             : (1, 1024, 50, 64)    => res4_1_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_1_branch2b             : (1, 1024, 50, 64)    => res4_1_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_1_branch2c             : (1, 1024, 50, 64)    => res4_1_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_1_branch2c_bn          : (1, 1024, 50, 64)    => res4_1_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_0_branch2c_bn          : (1, 1024, 50, 64)    => res4_1_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_1_branch2c_bn          : (1, 1024, 50, 64)    => res4_1_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_1_branch2c_bn          : (1, 1024, 50, 64)    => res4_2_branch2a             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_2_branch2a             : (1, 1024, 50, 64)    => res4_2_branch2a             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_2_branch2a             : (1, 1024, 50, 64)    => res4_2_branch2a             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_2_branch2a             : (1, 1024, 50, 64)    => res4_2_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_2_branch2b             : (1, 1024, 50, 64)    => res4_2_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_2_branch2b             : (1, 1024, 50, 64)    => res4_2_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_2_branch2b             : (1, 1024, 50, 64)    => res4_2_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_2_branch2c             : (1, 1024, 50, 64)    => res4_2_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_2_branch2c_bn          : (1, 1024, 50, 64)    => res4_2_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_1_branch2c_bn          : (1, 1024, 50, 64)    => res4_2_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_2_branch2c_bn          : (1, 1024, 50, 64)    => res4_2_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_2_branch2c_bn          : (1, 1024, 50, 64)    => res4_3_branch2a             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_3_branch2a             : (1, 1024, 50, 64)    => res4_3_branch2a             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_3_branch2a             : (1, 1024, 50, 64)    => res4_3_branch2a             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_3_branch2a             : (1, 1024, 50, 64)    => res4_3_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_3_branch2b             : (1, 1024, 50, 64)    => res4_3_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_3_branch2b             : (1, 1024, 50, 64)    => res4_3_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_3_branch2b             : (1, 1024, 50, 64)    => res4_3_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_3_branch2c             : (1, 1024, 50, 64)    => res4_3_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_3_branch2c_bn          : (1, 1024, 50, 64)    => res4_3_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_2_branch2c_bn          : (1, 1024, 50, 64)    => res4_3_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_3_branch2c_bn          : (1, 1024, 50, 64)    => res4_3_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_3_branch2c_bn          : (1, 1024, 50, 64)    => res4_4_branch2a             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_4_branch2a             : (1, 1024, 50, 64)    => res4_4_branch2a             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_4_branch2a             : (1, 1024, 50, 64)    => res4_4_branch2a             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_4_branch2a             : (1, 1024, 50, 64)    => res4_4_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_4_branch2b             : (1, 1024, 50, 64)    => res4_4_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_4_branch2b             : (1, 1024, 50, 64)    => res4_4_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_4_branch2b             : (1, 1024, 50, 64)    => res4_4_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_4_branch2c             : (1, 1024, 50, 64)    => res4_4_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_4_branch2c_bn          : (1, 1024, 50, 64)    => res4_4_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_3_branch2c_bn          : (1, 1024, 50, 64)    => res4_4_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_4_branch2c_bn          : (1, 1024, 50, 64)    => res4_4_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_4_branch2c_bn          : (1, 1024, 50, 64)    => res4_5_branch2a             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_5_branch2a             : (1, 1024, 50, 64)    => res4_5_branch2a             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_5_branch2a             : (1, 1024, 50, 64)    => res4_5_branch2a             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_5_branch2a             : (1, 1024, 50, 64)    => res4_5_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_5_branch2b             : (1, 1024, 50, 64)    => res4_5_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_5_branch2b             : (1, 1024, 50, 64)    => res4_5_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_5_branch2b             : (1, 1024, 50, 64)    => res4_5_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_5_branch2c             : (1, 1024, 50, 64)    => res4_5_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_5_branch2c_bn          : (1, 1024, 50, 64)    => res4_5_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_4_branch2c_bn          : (1, 1024, 50, 64)    => res4_5_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_5_branch2c_bn          : (1, 1024, 50, 64)    => res4_5_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_5_branch2c_bn          : (1, 1024, 50, 64)    => res4_6_branch2a             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_6_branch2a             : (1, 1024, 50, 64)    => res4_6_branch2a             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_6_branch2a             : (1, 1024, 50, 64)    => res4_6_branch2a             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_6_branch2a             : (1, 1024, 50, 64)    => res4_6_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_6_branch2b             : (1, 1024, 50, 64)    => res4_6_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_6_branch2b             : (1, 1024, 50, 64)    => res4_6_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_6_branch2b             : (1, 1024, 50, 64)    => res4_6_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_6_branch2c             : (1, 1024, 50, 64)    => res4_6_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_6_branch2c_bn          : (1, 1024, 50, 64)    => res4_6_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_5_branch2c_bn          : (1, 1024, 50, 64)    => res4_6_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_6_branch2c_bn          : (1, 1024, 50, 64)    => res4_6_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_6_branch2c_bn          : (1, 1024, 50, 64)    => res4_7_branch2a             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_7_branch2a             : (1, 1024, 50, 64)    => res4_7_branch2a             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_7_branch2a             : (1, 1024, 50, 64)    => res4_7_branch2a             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_7_branch2a             : (1, 1024, 50, 64)    => res4_7_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_7_branch2b             : (1, 1024, 50, 64)    => res4_7_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_7_branch2b             : (1, 1024, 50, 64)    => res4_7_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_7_branch2b             : (1, 1024, 50, 64)    => res4_7_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_7_branch2c             : (1, 1024, 50, 64)    => res4_7_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_7_branch2c_bn          : (1, 1024, 50, 64)    => res4_7_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_6_branch2c_bn          : (1, 1024, 50, 64)    => res4_7_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_7_branch2c_bn          : (1, 1024, 50, 64)    => res4_7_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_7_branch2c_bn          : (1, 1024, 50, 64)    => res4_8_branch2a             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_8_branch2a             : (1, 1024, 50, 64)    => res4_8_branch2a             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_8_branch2a             : (1, 1024, 50, 64)    => res4_8_branch2a             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_8_branch2a             : (1, 1024, 50, 64)    => res4_8_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_8_branch2b             : (1, 1024, 50, 64)    => res4_8_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_8_branch2b             : (1, 1024, 50, 64)    => res4_8_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_8_branch2b             : (1, 1024, 50, 64)    => res4_8_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_8_branch2c             : (1, 1024, 50, 64)    => res4_8_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_8_branch2c_bn          : (1, 1024, 50, 64)    => res4_8_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_7_branch2c_bn          : (1, 1024, 50, 64)    => res4_8_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_8_branch2c_bn          : (1, 1024, 50, 64)    => res4_8_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_8_branch2c_bn          : (1, 1024, 50, 64)    => res4_9_branch2a             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_9_branch2a             : (1, 1024, 50, 64)    => res4_9_branch2a             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_9_branch2a             : (1, 1024, 50, 64)    => res4_9_branch2a             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_9_branch2a             : (1, 1024, 50, 64)    => res4_9_branch2b             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_9_branch2b             : (1, 1024, 50, 64)    => res4_9_branch2b             : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_9_branch2b             : (1, 1024, 50, 64)    => res4_9_branch2b             : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_9_branch2b             : (1, 1024, 50, 64)    => res4_9_branch2c             : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_9_branch2c             : (1, 1024, 50, 64)    => res4_9_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_9_branch2c_bn          : (1, 1024, 50, 64)    => res4_9_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_8_branch2c_bn          : (1, 1024, 50, 64)    => res4_9_branch2c_bn          : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_9_branch2c_bn          : (1, 1024, 50, 64)    => res4_9_branch2c_bn          : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_9_branch2c_bn          : (1, 1024, 50, 64)    => res4_10_branch2a            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_10_branch2a            : (1, 1024, 50, 64)    => res4_10_branch2a            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_10_branch2a            : (1, 1024, 50, 64)    => res4_10_branch2a            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_10_branch2a            : (1, 1024, 50, 64)    => res4_10_branch2b            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_10_branch2b            : (1, 1024, 50, 64)    => res4_10_branch2b            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_10_branch2b            : (1, 1024, 50, 64)    => res4_10_branch2b            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_10_branch2b            : (1, 1024, 50, 64)    => res4_10_branch2c            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_10_branch2c            : (1, 1024, 50, 64)    => res4_10_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_10_branch2c_bn         : (1, 1024, 50, 64)    => res4_10_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_9_branch2c_bn          : (1, 1024, 50, 64)    => res4_10_branch2c_bn         : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_10_branch2c_bn         : (1, 1024, 50, 64)    => res4_10_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_10_branch2c_bn         : (1, 1024, 50, 64)    => res4_11_branch2a            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_11_branch2a            : (1, 1024, 50, 64)    => res4_11_branch2a            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_11_branch2a            : (1, 1024, 50, 64)    => res4_11_branch2a            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_11_branch2a            : (1, 1024, 50, 64)    => res4_11_branch2b            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_11_branch2b            : (1, 1024, 50, 64)    => res4_11_branch2b            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_11_branch2b            : (1, 1024, 50, 64)    => res4_11_branch2b            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_11_branch2b            : (1, 1024, 50, 64)    => res4_11_branch2c            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_11_branch2c            : (1, 1024, 50, 64)    => res4_11_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_11_branch2c_bn         : (1, 1024, 50, 64)    => res4_11_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_10_branch2c_bn         : (1, 1024, 50, 64)    => res4_11_branch2c_bn         : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_11_branch2c_bn         : (1, 1024, 50, 64)    => res4_11_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_11_branch2c_bn         : (1, 1024, 50, 64)    => res4_12_branch2a            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_12_branch2a            : (1, 1024, 50, 64)    => res4_12_branch2a            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_12_branch2a            : (1, 1024, 50, 64)    => res4_12_branch2a            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_12_branch2a            : (1, 1024, 50, 64)    => res4_12_branch2b            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_12_branch2b            : (1, 1024, 50, 64)    => res4_12_branch2b            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_12_branch2b            : (1, 1024, 50, 64)    => res4_12_branch2b            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_12_branch2b            : (1, 1024, 50, 64)    => res4_12_branch2c            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_12_branch2c            : (1, 1024, 50, 64)    => res4_12_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_12_branch2c_bn         : (1, 1024, 50, 64)    => res4_12_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_11_branch2c_bn         : (1, 1024, 50, 64)    => res4_12_branch2c_bn         : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_12_branch2c_bn         : (1, 1024, 50, 64)    => res4_12_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_12_branch2c_bn         : (1, 1024, 50, 64)    => res4_13_branch2a            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_13_branch2a            : (1, 1024, 50, 64)    => res4_13_branch2a            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_13_branch2a            : (1, 1024, 50, 64)    => res4_13_branch2a            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_13_branch2a            : (1, 1024, 50, 64)    => res4_13_branch2b            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_13_branch2b            : (1, 1024, 50, 64)    => res4_13_branch2b            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_13_branch2b            : (1, 1024, 50, 64)    => res4_13_branch2b            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_13_branch2b            : (1, 1024, 50, 64)    => res4_13_branch2c            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_13_branch2c            : (1, 1024, 50, 64)    => res4_13_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_13_branch2c_bn         : (1, 1024, 50, 64)    => res4_13_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: Sum)
# INFO net.py: 257: res4_12_branch2c_bn         : (1, 1024, 50, 64)    => res4_13_branch2c_bn         : (1, 1024, 50, 64)    ------|
# INFO net.py: 257: res4_13_branch2c_bn         : (1, 1024, 50, 64)    => res4_13_branch2c_bn         : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_13_branch2c_bn         : (1, 1024, 50, 64)    => res4_14_branch2a            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_14_branch2a            : (1, 1024, 50, 64)    => res4_14_branch2a            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_14_branch2a            : (1, 1024, 50, 64)    => res4_14_branch2a            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_14_branch2a            : (1, 1024, 50, 64)    => res4_14_branch2b            : (1, 1024, 50, 64)    ------- (op: Conv)
# INFO net.py: 257: res4_14_branch2b            : (1, 1024, 50, 64)    => res4_14_branch2b            : (1, 1024, 50, 64)    ------- (op: AffineChannel)
# INFO net.py: 257: res4_14_branch2b            : (1, 1024, 50, 64)    => res4_14_branch2b            : (1, 1024, 50, 64)    ------- (op: Relu)
# INFO net.py: 257: res4_14_branch2b            : (1, 1024, 50, 64)    => res4_14_branch2c            : (1, 1024, 50, 64)    ------- (op: Conv)
# ...
# INFO net.py: 257: rpn_bbox_pred_fpn3          : (1, 12, 100, 128)    => loss_rpn_bbox_fpn3          : ()                   ------- (op: SmoothL1Loss)
# INFO net.py: 257: rpn_bbox_targets_fpn3       : (1, 12, 100, 128)    => loss_rpn_bbox_fpn3          : ()                   ------|
# INFO net.py: 257: rpn_bbox_inside_weights_fpn3: (1, 12, 100, 128)    => loss_rpn_bbox_fpn3          : ()                   ------|
# INFO net.py: 257: rpn_bbox_outside_weights_fpn3: (1, 12, 100, 128)    => loss_rpn_bbox_fpn3          : ()                   ------|
# INFO net.py: 257: rpn_labels_int32_wide_fpn4  : (1, 3, 84, 84)       => rpn_labels_int32_fpn4       : (1, 3, 50, 64)       ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_cls_logits_fpn4         : (1, 3, 50, 64)       => rpn_labels_int32_fpn4       : (1, 3, 50, 64)       ------|
# INFO net.py: 257: rpn_bbox_targets_wide_fpn4  : (1, 12, 84, 84)      => rpn_bbox_targets_fpn4       : (1, 12, 50, 64)      ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_bbox_pred_fpn4          : (1, 12, 50, 64)      => rpn_bbox_targets_fpn4       : (1, 12, 50, 64)      ------|
# INFO net.py: 257: rpn_bbox_inside_weights_wide_fpn4: (1, 12, 84, 84)      => rpn_bbox_inside_weights_fpn4: (1, 12, 50, 64)      ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_bbox_pred_fpn4          : (1, 12, 50, 64)      => rpn_bbox_inside_weights_fpn4: (1, 12, 50, 64)      ------|
# INFO net.py: 257: rpn_bbox_outside_weights_wide_fpn4: (1, 12, 84, 84)      => rpn_bbox_outside_weights_fpn4: (1, 12, 50, 64)      ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_bbox_pred_fpn4          : (1, 12, 50, 64)      => rpn_bbox_outside_weights_fpn4: (1, 12, 50, 64)      ------|
# INFO net.py: 257: rpn_cls_logits_fpn4         : (1, 3, 50, 64)       => loss_rpn_cls_fpn4           : ()                   ------- (op: SigmoidCrossEntropyLoss)
# INFO net.py: 257: rpn_labels_int32_fpn4       : (1, 3, 50, 64)       => loss_rpn_cls_fpn4           : ()                   ------|
# INFO net.py: 257: rpn_bbox_pred_fpn4          : (1, 12, 50, 64)      => loss_rpn_bbox_fpn4          : ()                   ------- (op: SmoothL1Loss)
# INFO net.py: 257: rpn_bbox_targets_fpn4       : (1, 12, 50, 64)      => loss_rpn_bbox_fpn4          : ()                   ------|
# INFO net.py: 257: rpn_bbox_inside_weights_fpn4: (1, 12, 50, 64)      => loss_rpn_bbox_fpn4          : ()                   ------|
# INFO net.py: 257: rpn_bbox_outside_weights_fpn4: (1, 12, 50, 64)      => loss_rpn_bbox_fpn4          : ()                   ------|
# INFO net.py: 257: rpn_labels_int32_wide_fpn5  : (1, 3, 42, 42)       => rpn_labels_int32_fpn5       : (1, 3, 25, 32)       ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_cls_logits_fpn5         : (1, 3, 25, 32)       => rpn_labels_int32_fpn5       : (1, 3, 25, 32)       ------|
# INFO net.py: 257: rpn_bbox_targets_wide_fpn5  : (1, 12, 42, 42)      => rpn_bbox_targets_fpn5       : (1, 12, 25, 32)      ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_bbox_pred_fpn5          : (1, 12, 25, 32)      => rpn_bbox_targets_fpn5       : (1, 12, 25, 32)      ------|
# INFO net.py: 257: rpn_bbox_inside_weights_wide_fpn5: (1, 12, 42, 42)      => rpn_bbox_inside_weights_fpn5: (1, 12, 25, 32)      ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_bbox_pred_fpn5          : (1, 12, 25, 32)      => rpn_bbox_inside_weights_fpn5: (1, 12, 25, 32)      ------|
# INFO net.py: 257: rpn_bbox_outside_weights_wide_fpn5: (1, 12, 42, 42)      => rpn_bbox_outside_weights_fpn5: (1, 12, 25, 32)      ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_bbox_pred_fpn5          : (1, 12, 25, 32)      => rpn_bbox_outside_weights_fpn5: (1, 12, 25, 32)      ------|
# INFO net.py: 257: rpn_cls_logits_fpn5         : (1, 3, 25, 32)       => loss_rpn_cls_fpn5           : ()                   ------- (op: SigmoidCrossEntropyLoss)
# INFO net.py: 257: rpn_labels_int32_fpn5       : (1, 3, 25, 32)       => loss_rpn_cls_fpn5           : ()                   ------|
# INFO net.py: 257: rpn_bbox_pred_fpn5          : (1, 12, 25, 32)      => loss_rpn_bbox_fpn5          : ()                   ------- (op: SmoothL1Loss)
# INFO net.py: 257: rpn_bbox_targets_fpn5       : (1, 12, 25, 32)      => loss_rpn_bbox_fpn5          : ()                   ------|
# INFO net.py: 257: rpn_bbox_inside_weights_fpn5: (1, 12, 25, 32)      => loss_rpn_bbox_fpn5          : ()                   ------|
# INFO net.py: 257: rpn_bbox_outside_weights_fpn5: (1, 12, 25, 32)      => loss_rpn_bbox_fpn5          : ()                   ------|
# INFO net.py: 257: rpn_labels_int32_wide_fpn6  : (1, 3, 21, 21)       => rpn_labels_int32_fpn6       : (1, 3, 13, 16)       ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_cls_logits_fpn6         : (1, 3, 13, 16)       => rpn_labels_int32_fpn6       : (1, 3, 13, 16)       ------|
# INFO net.py: 257: rpn_bbox_targets_wide_fpn6  : (1, 12, 21, 21)      => rpn_bbox_targets_fpn6       : (1, 12, 13, 16)      ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_bbox_pred_fpn6          : (1, 12, 13, 16)      => rpn_bbox_targets_fpn6       : (1, 12, 13, 16)      ------|
# INFO net.py: 257: rpn_bbox_inside_weights_wide_fpn6: (1, 12, 21, 21)      => rpn_bbox_inside_weights_fpn6: (1, 12, 13, 16)      ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_bbox_pred_fpn6          : (1, 12, 13, 16)      => rpn_bbox_inside_weights_fpn6: (1, 12, 13, 16)      ------|
# INFO net.py: 257: rpn_bbox_outside_weights_wide_fpn6: (1, 12, 21, 21)      => rpn_bbox_outside_weights_fpn6: (1, 12, 13, 16)      ------- (op: SpatialNarrowAs)
# INFO net.py: 257: rpn_bbox_pred_fpn6          : (1, 12, 13, 16)      => rpn_bbox_outside_weights_fpn6: (1, 12, 13, 16)      ------|
# INFO net.py: 257: rpn_cls_logits_fpn6         : (1, 3, 13, 16)       => loss_rpn_cls_fpn6           : ()                   ------- (op: SigmoidCrossEntropyLoss)
# INFO net.py: 257: rpn_labels_int32_fpn6       : (1, 3, 13, 16)       => loss_rpn_cls_fpn6           : ()                   ------|
# INFO net.py: 257: rpn_bbox_pred_fpn6          : (1, 12, 13, 16)      => loss_rpn_bbox_fpn6          : ()                   ------- (op: SmoothL1Loss)
# INFO net.py: 257: rpn_bbox_targets_fpn6       : (1, 12, 13, 16)      => loss_rpn_bbox_fpn6          : ()                   ------|
# INFO net.py: 257: rpn_bbox_inside_weights_fpn6: (1, 12, 13, 16)      => loss_rpn_bbox_fpn6          : ()                   ------|
# INFO net.py: 257: rpn_bbox_outside_weights_fpn6: (1, 12, 13, 16)      => loss_rpn_bbox_fpn6          : ()                   ------|
# INFO net.py: 257: fpn_res2_2_sum              : (1, 256, 200, 256)   => roi_feat_fpn2               : (248, 256, 7, 7)     ------- (op: RoIAlign)
# INFO net.py: 257: rois_fpn2                   : (248, 5)             => roi_feat_fpn2               : (248, 256, 7, 7)     ------|
# INFO net.py: 257: fpn_res3_3_sum              : (1, 256, 100, 128)   => roi_feat_fpn3               : (84, 256, 7, 7)      ------- (op: RoIAlign)
# INFO net.py: 257: rois_fpn3                   : (84, 5)              => roi_feat_fpn3               : (84, 256, 7, 7)      ------|
# INFO net.py: 257: fpn_res4_22_sum             : (1, 256, 50, 64)     => roi_feat_fpn4               : (163, 256, 7, 7)     ------- (op: RoIAlign)
# INFO net.py: 257: rois_fpn4                   : (163, 5)             => roi_feat_fpn4               : (163, 256, 7, 7)     ------|
# INFO net.py: 257: fpn_res5_2_sum              : (1, 256, 25, 32)     => roi_feat_fpn5               : (17, 256, 7, 7)      ------- (op: RoIAlign)
# INFO net.py: 257: rois_fpn5                   : (17, 5)              => roi_feat_fpn5               : (17, 256, 7, 7)      ------|
# INFO net.py: 257: roi_feat_fpn2               : (248, 256, 7, 7)     => roi_feat_shuffled           : (512, 256, 7, 7)     ------- (op: Concat)
# INFO net.py: 257: roi_feat_fpn3               : (84, 256, 7, 7)      => roi_feat_shuffled           : (512, 256, 7, 7)     ------|
# INFO net.py: 257: roi_feat_fpn4               : (163, 256, 7, 7)     => roi_feat_shuffled           : (512, 256, 7, 7)     ------|
# INFO net.py: 257: roi_feat_fpn5               : (17, 256, 7, 7)      => roi_feat_shuffled           : (512, 256, 7, 7)     ------|
# INFO net.py: 257: roi_feat_shuffled           : (512, 256, 7, 7)     => roi_feat                    : (512, 256, 7, 7)     ------- (op: BatchPermutation)
# INFO net.py: 257: rois_idx_restore_int32      : (512,)               => roi_feat                    : (512, 256, 7, 7)     ------|
# INFO net.py: 257: roi_feat                    : (512, 256, 7, 7)     => fc6                         : (512, 1024)          ------- (op: FC)
# INFO net.py: 257: fc6                         : (512, 1024)          => fc6                         : (512, 1024)          ------- (op: Relu)
# INFO net.py: 257: fc6                         : (512, 1024)          => fc7                         : (512, 1024)          ------- (op: FC)
# INFO net.py: 257: fc7                         : (512, 1024)          => fc7                         : (512, 1024)          ------- (op: Relu)
# INFO net.py: 257: fc7                         : (512, 1024)          => cls_score                   : (512, 601)           ------- (op: FC)
# INFO net.py: 257: fc7                         : (512, 1024)          => bbox_pred                   : (512, 2404)          ------- (op: FC)
# INFO net.py: 257: cls_score                   : (512, 601)           => cls_prob                    : (512, 601)           ------- (op: SoftmaxWithLoss)
# INFO net.py: 257: labels_int32                : (512,)               => cls_prob                    : (512, 601)           ------|
# INFO net.py: 257: bbox_pred                   : (512, 2404)          => loss_bbox                   : ()                   ------- (op: SmoothL1Loss)
# INFO net.py: 257: bbox_targets                : (512, 2404)          => loss_bbox                   : ()                   ------|
# INFO net.py: 257: bbox_inside_weights         : (512, 2404)          => loss_bbox                   : ()                   ------|
# INFO net.py: 257: bbox_outside_weights        : (512, 2404)          => loss_bbox                   : ()                   ------|
# INFO net.py: 257: cls_prob                    : (512, 601)           => accuracy_cls                : ()                   ------- (op: Accuracy)
# INFO net.py: 257: labels_int32                : (512,)               => accuracy_cls                : ()                   ------|
# INFO net.py: 261: End of model: generalized_rcnn
# json_stats: {"accuracy_cls": 0.000000, "eta": "17 days, 13:32:57", "iter": 0, "loss": 6.760367, "loss_bbox": 0.518648, "loss_cls": 6.205635, "loss_rpn_bbox_fpn2": 0.000000, "loss_rpn_bbox_fpn3": 0.000000, "loss_rpn_bbox_fpn4": 0.000000, "loss_rpn_bbox_fpn5": 0.011348, "loss_rpn_bbox_fpn6": 0.009093, "loss_rpn_cls_fpn2": 0.000545, "loss_rpn_cls_fpn3": 0.001829, "loss_rpn_cls_fpn4": 0.000063, "loss_rpn_cls_fpn5": 0.013205, "loss_rpn_cls_fpn6": 0.000001, "lr": 0.000333, "mb_qsize": 64, "mem": 4922, "time": 2.529296}
# json_stats: {"accuracy_cls": 0.910156, "eta": "2 days, 9:03:35", "iter": 20, "loss": 2.806715, "loss_bbox": 0.115326, "loss_cls": 1.915013, "loss_rpn_bbox_fpn2": 0.000000, "loss_rpn_bbox_fpn3": 0.000000, "loss_rpn_bbox_fpn4": 0.000000, "loss_rpn_bbox_fpn5": 0.000000, "loss_rpn_bbox_fpn6": 0.011855, "loss_rpn_cls_fpn2": 0.000016, "loss_rpn_cls_fpn3": 0.000027, "loss_rpn_cls_fpn4": 0.006045, "loss_rpn_cls_fpn5": 0.000478, "loss_rpn_cls_fpn6": 0.002203, "lr": 0.000467, "mb_qsize": 64, "mem": 5880, "time": 0.342371}
# E0728 00:08:46.969693 19009 pybind_state.h:422] Exception encountered running PythonOp function: ValueError: could not broadcast input array from shape (4) into shape (0)
#
# At:
#   /home/working_directory/ml/kaggle/OpenImagesObjectDetection/detectron_source/detectron/roi_data/fast_rcnn.py(233): _expand_bbox_targets
#   /home/working_directory/ml/kaggle/OpenImagesObjectDetection/detectron_source/detectron/roi_data/fast_rcnn.py(174): _sample_rois
#   /home/working_directory/ml/kaggle/OpenImagesObjectDetection/detectron_source/detectron/roi_data/fast_rcnn.py(112): add_fast_rcnn_blobs
#   /home/working_directory/ml/kaggle/OpenImagesObjectDetection/detectron_source/detectron/ops/collect_and_distribute_fpn_rpn_proposals.py(62): forward
# terminate called after throwing an instance of 'caffe2::EnforceNotMet'
#   what():  [enforce fail at pybind_state.h:423] . Exception encountered running PythonOp function: ValueError: could not broadcast input array from shape (4) into shape (0)
#
# At:
#   /home/working_directory/ml/kaggle/OpenImagesObjectDetection/detectron_source/detectron/roi_data/fast_rcnn.py(233): _expand_bbox_targets
#   /home/working_directory/ml/kaggle/OpenImagesObjectDetection/detectron_source/detectron/roi_data/fast_rcnn.py(174): _sample_rois
#   /home/working_directory/ml/kaggle/OpenImagesObjectDetection/detectron_source/detectron/roi_data/fast_rcnn.py(112): add_fast_rcnn_blobs
#   /home/working_directory/ml/kaggle/OpenImagesObjectDetection/detectron_source/detectron/ops/collect_and_distribute_fpn_rpn_proposals.py(62): forward
#  Error from operator:
# input: "gpu_0/rpn_rois_fpn2" input: "gpu_0/rpn_rois_fpn3" input: "gpu_0/rpn_rois_fpn4" input: "gpu_0/rpn_rois_fpn5" input: "gpu_0/rpn_rois_fpn6" input: "gpu_0/rpn_roi_probs_fpn2" input: "gpu_0/rpn_roi_probs_fpn3" input: "gpu_0/rpn_roi_probs_fpn4" input: "gpu_0/rpn_roi_probs_fpn5" input: "gpu_0/rpn_roi_probs_fpn6" input: "gpu_0/roidb" input: "gpu_0/im_info" output: "gpu_0/rois" output: "gpu_0/labels_int32" output: "gpu_0/bbox_targets" output: "gpu_0/bbox_inside_weights" output: "gpu_0/bbox_outside_weights" output: "gpu_0/rois_fpn2" output: "gpu_0/rois_fpn3" output: "gpu_0/rois_fpn4" output: "gpu_0/rois_fpn5" output: "gpu_0/rois_idx_restore_int32" name: "CollectAndDistributeFpnRpnProposalsOp:gpu_0/rpn_rois_fpn2,gpu_0/rpn_rois_fpn3,gpu_0/rpn_rois_fpn4,gpu_0/rpn_rois_fpn5,gpu_0/rpn_rois_fpn6,gpu_0/rpn_roi_probs_fpn2,gpu_0/rpn_roi_probs_fpn3,gpu_0/rpn_roi_probs_fpn4,gpu_0/rpn_roi_probs_fpn5,gpu_0/rpn_roi_probs_fpn6,gpu_0/roidb,gpu_0/im_info" type: "Python" arg { name: "grad_input_indices" } arg { name: "token" s: "forward:5" } arg { name: "grad_output_indices" } device_option { device_type: 0 }Error from operator:
# input: "gpu_0/rpn_rois_fpn2" input: "gpu_0/rpn_rois_fpn3" input: "gpu_0/rpn_rois_fpn4" input: "gpu_0/rpn_rois_fpn5" input: "gpu_0/rpn_rois_fpn6" input: "gpu_0/rpn_roi_probs_fpn2" input: "gpu_0/rpn_roi_probs_fpn3" input: "gpu_0/rpn_roi_probs_fpn4" input: "gpu_0/rpn_roi_probs_fpn5" input: "gpu_0/rpn_roi_probs_fpn6" input: "gpu_0/roidb" input: "gpu_0/im_info" output: "gpu_0/rois" output: "gpu_0/labels_int32" output: "gpu_0/bbox_targets" output: "gpu_0/bbox_inside_weights" output: "gpu_0/bbox_outside_weights" output: "gpu_0/rois_fpn2" output: "gpu_0/rois_fpn3" output: "gpu_0/rois_fpn4" output: "gpu_0/rois_fpn5" output: "gpu_0/rois_idx_restore_int32" name: "CollectAndDistributeFpnRpnProposalsOp:gpu_0/rpn_rois_fpn2,gpu_0/rpn_rois_fpn3,gpu_0/rpn_rois_fpn4,gpu_0/rpn_rois_fpn5,gpu_0/rpn_rois_fpn6,gpu_0/rpn_roi_probs_fpn2,gpu_0/rpn_roi_probs_fpn3,gpu_0/rpn_roi_probs_fpn4,gpu_0/rpn_roi_probs_fpn5,gpu_0/rpn_roi_probs_fpn6,gpu_0/roidb,gpu_0/im_info" type: "Python" arg { name: "grad_input_indices" } arg { name: "token" s: "forward:5" } arg { name: "grad_output_indices" } device_option { device_type: 1 cuda_gpu_id: 0 }
# *** Aborted at 1532736526 (unix time) try "date -d @1532736526" if you are using GNU date ***
# PC: @     0x7f0a9cbb5428 gsignal
# *** SIGABRT (@0x3c04) received by PID 15364 (TID 0x7f08ecbfd700) from PID 15364; stack trace: ***
#     @     0x7f0a9cf5b390 (unknown)
#     @     0x7f0a9cbb5428 gsignal
#     @     0x7f0a9cbb702a abort
#     @     0x7f0a96c6384d __gnu_cxx::__verbose_terminate_handler()
#     @     0x7f0a96c616b6 (unknown)
#     @     0x7f0a96c61701 std::terminate()
#     @     0x7f0a96c8cd38 (unknown)
#     @     0x7f0a9cf516ba start_thread
#     @     0x7f0a9cc8741d clone
#     @                0x0 (unknown)
# Aborted (core dumped)
